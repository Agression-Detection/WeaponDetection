# %%
import sagemaker
from sagemaker.pytorch import PyTorch

# %%
checkpoint_s3_uri = 's3://agression-model/checkpoints/'
local_checkpoint_dir = '/opt/ml/checkpoints'

role = sagemaker.get_execution_role()
estimator = PyTorch(
    entry_point='train.py',
    source_dir='./src',
    role=role,
    instance_type='ml.g4dn.xlarge',
    instance_count=2,
    framework_version='2.0.0',
    py_version='py310',
    distribution={
        'torch_distributed': {
            'enabled': True
        }
    },
    hyperparameters={
        'epochs': 10,
        'batch-size': 32,
        'checkpoint-dir': local_checkpoint_dir,
    },

    output_path='s3://agression-model/output/',
    checkpoint_s3_uri=checkpoint_s3_uri,
    checkpoint_local_path=local_checkpoint_dir,
)
estimator.fit({
    'training': 's3://agression-model/'
})
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:28                                                                                   │
# │                                                                                                  │
# │   25 │   checkpoint_s3_uri=checkpoint_s3_uri,                                                    │
# │   26 │   checkpoint_local_path=local_checkpoint_dir,                                             │
# │   27 )                                                                                           │
# │ ❱ 28 estimator.fit({                                                                             │
# │   29 │   'training': 's3://agression-model/'                                                     │
# │   30 })                                                                                          │
# │   31                                                                                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/telemetry/telemetry_logging.py:167 in wrapper  │
# │                                                                                                  │
# │   164 │   │   │   │   │   caught_ex = e                                                          │
# │   165 │   │   │   │   finally:                                                                   │
# │   166 │   │   │   │   │   if caught_ex:                                                          │
# │ ❱ 167 │   │   │   │   │   │   raise caught_ex                                                    │
# │   168 │   │   │   │   │   return response  # pylint: disable=W0150                               │
# │   169 │   │   │   else:                                                                          │
# │   170 │   │   │   │   logger.debug(                                                              │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/telemetry/telemetry_logging.py:138 in wrapper  │
# │                                                                                                  │
# │   135 │   │   │   │   start_timer = perf_counter()                                               │
# │   136 │   │   │   │   try:                                                                       │
# │   137 │   │   │   │   │   # Call the original function                                           │
# │ ❱ 138 │   │   │   │   │   response = func(*args, **kwargs)                                       │
# │   139 │   │   │   │   │   stop_timer = perf_counter()                                            │
# │   140 │   │   │   │   │   elapsed = stop_timer - start_timer                                     │
# │   141 │   │   │   │   │   extra += f"&x-latency={round(elapsed, 2)}"                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/workflow/pipeline_context.py:346 in wrapper    │
# │                                                                                                  │
# │   343 │   │   │                                                                                  │
# │   344 │   │   │   return _StepArguments(retrieve_caller_name(self_instance), run_func, *args,    │
# │   345 │   │                                                                                      │
# │ ❱ 346 │   │   return run_func(*args, **kwargs)                                                   │
# │   347 │                                                                                          │
# │   348 │   return wrapper                                                                         │
# │   349                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/estimator.py:1370 in fit                       │
# │                                                                                                  │
# │   1367 │   │   │   None or pipeline step arguments in case the Estimator instance is built with  │
# │   1368 │   │   │   :class:`~sagemaker.workflow.pipeline_context.PipelineSession`                 │
# │   1369 │   │   """                                                                               │
# │ ❱ 1370 │   │   self._prepare_for_training(job_name=job_name)                                     │
# │   1371 │   │                                                                                     │
# │   1372 │   │   experiment_config = check_and_get_run_experiment_config(experiment_config)        │
# │   1373 │   │   self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_confi  │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/estimator.py:3608 in _prepare_for_training     │
# │                                                                                                  │
# │   3605 │   │   │   │   specified, one is generated, using the base name given to the             │
# │   3606 │   │   │   │   constructor if applicable.                                                │
# │   3607 │   │   """                                                                               │
# │ ❱ 3608 │   │   super(Framework, self)._prepare_for_training(job_name=job_name)                   │
# │   3609 │   │                                                                                     │
# │   3610 │   │   self._validate_and_set_debugger_configs()                                         │
# │   3611                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/estimator.py:967 in _prepare_for_training      │
# │                                                                                                  │
# │    964 │   │   │   │   script = self.uploaded_code.script_name                                   │
# │    965 │   │   │   │   self.code_uri = self.uploaded_code.s3_prefix                              │
# │    966 │   │   │   else:                                                                         │
# │ ❱  967 │   │   │   │   self.uploaded_code = self._stage_user_code_in_s3()                        │
# │    968 │   │   │   │   code_dir = self.uploaded_code.s3_prefix                                   │
# │    969 │   │   │   │   script = self.uploaded_code.script_name                                   │
# │    970                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/estimator.py:1049 in _stage_user_code_in_s3    │
# │                                                                                                  │
# │   1046 │   │   │   │   │   output_bucket, _ = parse_s3_url(self.output_path)                     │
# │   1047 │   │   │   │   │   kms_key = self.output_kms_key if code_bucket == output_bucket else N  │
# │   1048 │   │                                                                                     │
# │ ❱ 1049 │   │   return tar_and_upload_dir(                                                        │
# │   1050 │   │   │   session=self.sagemaker_session.boto_session,                                  │
# │   1051 │   │   │   bucket=code_bucket,                                                           │
# │   1052 │   │   │   s3_key_prefix=code_s3_prefix,                                                 │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/fw_utils.py:459 in tar_and_upload_dir          │
# │                                                                                                  │
# │    456 │                                                                                         │
# │    457 │   try:                                                                                  │
# │    458 │   │   source_files = _list_files_to_compress(script, directory) + dependencies          │
# │ ❱  459 │   │   tar_file = sagemaker.utils.create_tar_file(                                       │
# │    460 │   │   │   source_files, os.path.join(tmp, _TAR_SOURCE_FILENAME)                         │
# │    461 │   │   )                                                                                 │
# │    462                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/utils.py:470 in create_tar_file                │
# │                                                                                                  │
# │    467 │   with tarfile.open(filename, mode="w:gz", dereference=True) as t:                      │
# │    468 │   │   for sf in source_files:                                                           │
# │    469 │   │   │   # Add all files from the directory into the root of the directory structure   │
# │ ❱  470 │   │   │   t.add(sf, arcname=os.path.basename(sf))                                       │
# │    471 │   return filename                                                                       │
# │    472                                                                                           │
# │    473                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/tarfile.py:2197 in add                                                 │
# │                                                                                                  │
# │   2194 │   │   self._dbg(1, name)                                                                │
# │   2195 │   │                                                                                     │
# │   2196 │   │   # Create a TarInfo object from the file.                                          │
# │ ❱ 2197 │   │   tarinfo = self.gettarinfo(name, arcname)                                          │
# │   2198 │   │                                                                                     │
# │   2199 │   │   if tarinfo is None:                                                               │
# │   2200 │   │   │   self._dbg(1, "tarfile: Unsupported type %r" % name)                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/tarfile.py:2072 in gettarinfo                                          │
# │                                                                                                  │
# │   2069 │   │   │   if not self.dereference:                                                      │
# │   2070 │   │   │   │   statres = os.lstat(name)                                                  │
# │   2071 │   │   │   else:                                                                         │
# │ ❱ 2072 │   │   │   │   statres = os.stat(name)                                                   │
# │   2073 │   │   else:                                                                             │
# │   2074 │   │   │   statres = os.fstat(fileobj.fileno())                                          │
# │   2075 │   │   linkname = ""                                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: [Errno 2] No such file or directory: './data'
